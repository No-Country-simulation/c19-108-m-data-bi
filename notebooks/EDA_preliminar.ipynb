# %%
r.Imagen('/content/drive/MyDrive/NoCountry_RiesgoCrediticio/banner_consultora_ayc.png', (20,10))

# %% [markdown]
# #### Para Google Colab

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Importaciones

# %%
import numpy as np
import pandas as pd
import os # en el caso que se trabaje en el entorno de colab
import pyarrow as pa
import pyarrow.parquet as pq

os.chdir('/content/drive/MyDrive/NoCountry_RiesgoCrediticio/recursos_y_notebooks') # en el caso de que se trabaje en google colab

# %load_ext autoreload
# %autoreload 2

import resources as r

# Este codigo Pone un limite grande para el ancho y sin limite para el largo de un output
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', 1000)
pd.set_option('display.width', 1000)

# %%
lista_produccion = os.listdir('../raw/')

# %% [markdown]
# # <h1 align= 'center'><u><strong></strong>Datos</u></h1>

# %% [markdown]
# ### Instanciamos los dataframes

# %%
cotizaciones = pd.read_parquet('../stage/Cotizaciones_empresas.parquet')

# %%
pozos = pd.read_parquet('../stage/pozos.parquet')

# %%
precio_petroleo = pd.read_parquet('../stage/precio_del_petroleo_en_el_mundo.parquet')

# %%
precio_crudo_barril = pd.read_parquet('../stage/precio_internacional_del_crudo(por_barril).parquet')

# %%
prod_gyp = pd.read_parquet('../stage/produccion_petroleo_y_gas.parquet')

# %%
rentas_petroleo = pd.read_parquet('../stage/rentas_del_petróleo_(% del PIB)_Arg.parquet')

# %%
inversiones = pd.read_parquet('../stage/Inversiones 2020-2024.parquet')

# %% [markdown]
# # <h1 align= 'center'><u><strong>EDA Preliminar</strong></u>

# %% [markdown]
# ## Cotizaciones

# %%
r.descripcion_distribucion(cotizaciones)
# Out:
# Estadísticas Básicas
#
#
# count           2378
# unique          1238
# top       2024-07-10
# freq               3
# Name: Fecha, dtype: object
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------
# Estadísticas Básicas
#
#
# count     2378.000000
# mean      3963.465559
# std       4626.545423
# min          9.620000
# 25%       1054.562500
# 50%       2079.500000
# 75%       4241.457500
# max      21375.000000
# Name: Cierre/Ultimo, dtype: float64
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------
# ...

# %% [markdown]
# ## Pozos

# %%
r.descripcion_distribucion(pozos)
# Out:
# Estadísticas Básicas
#
#
# count     83990.000000
# mean     101577.432682
# std       43033.904028
# min         212.000000
# 25%       69694.250000
# 50%      109706.500000
# 75%      132723.750000
# max      165400.000000
# Name: idpozo, dtype: float64
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------
# Estadísticas Básicas
#
#
# count    83990.000000
# mean       -42.357689
# std          5.243063
# min        -69.415770
# 25%        -46.334014
# 50%        -45.716160
# 75%        -38.015883
# max        -22.002550
# Name: Latitud, dtype: float64
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------
# ...

# %% [markdown]
# ## Precio Petroleo

# %%
r.descripcion_distribucion(precio_petroleo)
# Out:
# Estadísticas Básicas
#
#
# count               181
# unique              181
# top       United States
# freq                  1
# Name: Pais, dtype: object
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------
# Estadísticas Básicas
#
#
# count       181.000000
# mean     128472.787536
# std      207973.306735
# min          51.000000
# 25%        8000.000000
# 50%       40000.000000
# 75%      152404.000000
# max      981203.000000
# Name: Consumo_diario_barriles, dtype: float64
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------
# ...

# %% [markdown]
# ## Precio Crudo Barril

# %%
r.descripcion_distribucion(precio_crudo_barril)
# Out:
# Estadísticas Básicas
#
#
# count            494
# unique           494
# top       1983-06-01
# freq               1
# Name: Fecha, dtype: object
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------
# Estadísticas Básicas
#
#
# count    494.000000
# mean      46.325888
# std       29.083015
# min       10.420000
# 25%       20.420000
# 50%       33.685000
# 75%       69.322500
# max      140.000000
# Name: Precio, dtype: float64
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------
# ...

# %% [markdown]
# ## Produccion Gas y Petroleo

# %%
r.descripcion_distribucion(prod_gyp)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# ## Rentas Petroleo

# %%
# No tiene sentido el realizar un analisis grafico de este fichero, ya que consta de un solo registro
# r.descripcion_distribucion(rentas_petroleo)

# %% [markdown]
# ## Inversiones

# %%
r.descripcion_distribucion(inversiones)
# Out:
# Estadísticas Básicas
#
#
# count                          232
# unique                          60
# top       PETROLERA EL TREBOL S.A.
# freq                             5
# Name: Empresa, dtype: object
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------
# Estadísticas Básicas
#
#
# count    232.000000
# mean       6.248547
# std       14.224620
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        2.850000
# max       89.760000
# Name: Suma de Millones u$s Exploracion, dtype: float64
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------
# ...

# %% [markdown]
# # <h1 align= 'center'><u><strong>Conclusiones</strong></u>
